# %% [markdown]
# <a href="https://colab.research.google.com/github/Fasiloc/Machine_Learning_learn-repo/blob/main/Classes/Day_24_pg_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('Diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
x = df.drop('Outcome',axis=1)
y = df['Outcome']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
sc = StandardScaler()
scaler = sc.fit(x_train)
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
mlp_clf = MLPClassifier(hidden_layer_sizes=(20),
                        max_iter=1000,activation='relu',
                        verbose=True,
                        solver='adam')

mlp_clf.fit(x_train_scaled,y_train)
# Out:
# Iteration 1, loss = 0.79804871
# Iteration 2, loss = 0.78587585
# Iteration 3, loss = 0.77420710
# Iteration 4, loss = 0.76372817
# Iteration 5, loss = 0.75305588
# Iteration 6, loss = 0.74358746
# Iteration 7, loss = 0.73381773
# Iteration 8, loss = 0.72365367
# Iteration 9, loss = 0.71443433
# Iteration 10, loss = 0.70527483
# Iteration 11, loss = 0.69656648
# Iteration 12, loss = 0.68812291
# Iteration 13, loss = 0.67933599
# Iteration 14, loss = 0.67128848
# Iteration 15, loss = 0.66402246
# Iteration 16, loss = 0.65702685
# Iteration 17, loss = 0.65068211
# Iteration 18, loss = 0.64425390
# Iteration 19, loss = 0.63827280
# Iteration 20, loss = 0.63184727
# Iteration 21, loss = 0.62586061
# Iteration 22, loss = 0.62020828
# Iteration 23, loss = 0.61448131
# Iteration 24, loss = 0.60916847
# Iteration 25, loss = 0.60418095
# Iteration 26, loss = 0.59959141
# Iteration 27, loss = 0.59494859
# Iteration 28, loss = 0.59091320
# Iteration 29, loss = 0.58657073
# ...

# %%
y_pred = mlp_clf.predict(x_test_scaled)
print('Accuracy :',accuracy_score(y_test,y_pred))
# Out:
# Accuracy : 0.7922077922077922

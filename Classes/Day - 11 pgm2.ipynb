# %%
import pandas as pd

# %%
import numpy as np
from sklearn import tree

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as pt

# %%
col_names=['pregnent', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'ped','age', 'label']

# %%
dataset=pd.read_csv("diabetes.csv")

# %%
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
dataset.columns = col_names

# %%
feature_cols=['pregnent', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'ped']

# %%
x=dataset[feature_cols]

# %%
dataset.head()
# Out:
#    pregnent  glucose  bp  skin  insulin   bmi    ped  age  label
# 0         6      148  72    35        0  33.6  0.627   50      1
# 1         1       85  66    29        0  26.6  0.351   31      0
# 2         8      183  64     0        0  23.3  0.672   32      1
# 3         1       89  66    23       94  28.1  0.167   21      0
# 4         0      137  40    35      168  43.1  2.288   33      1

# %%
y=dataset.label

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=DecisionTreeClassifier()

# %%
model=model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
print("accuracy", metrics.accuracy_score(y_test,y_pred))
# Out:
# accuracy 0.7142857142857143

# %%
tree.plot_tree(model)
# Out:
# [Text(152.06918361244018, 211.04470588235293, 'X[1] <= 127.5\ngini = 0.453\nsamples = 614\nvalue = [401, 213]'),
#  Text(58.24458732057416, 198.25411764705882, 'X[5] <= 26.95\ngini = 0.314\nsamples = 390\nvalue = [314, 76]'),
#  Text(20.82488038277512, 185.4635294117647, 'X[2] <= 94.0\ngini = 0.05\nsamples = 116\nvalue = [113, 3]'),
#  Text(12.81531100478469, 172.6729411764706, 'X[5] <= 26.45\ngini = 0.035\nsamples = 112\nvalue = [110, 2]'),
#  Text(6.407655502392345, 159.88235294117646, 'X[6] <= 0.675\ngini = 0.019\nsamples = 105\nvalue = [104, 1]'),
#  Text(3.2038277511961724, 147.09176470588235, 'gini = 0.0\nsamples = 91\nvalue = [91, 0]'),
#  Text(9.611483253588517, 147.09176470588235, 'X[6] <= 0.705\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(6.407655502392345, 134.30117647058825, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(12.81531100478469, 134.30117647058825, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(19.222966507177034, 159.88235294117646, 'X[0] <= 6.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(16.019138755980862, 147.09176470588235, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(22.426794258373207, 147.09176470588235, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(28.83444976076555, 172.6729411764706, 'X[5] <= 11.2\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(25.63062200956938, 159.88235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(32.038277511961724, 159.88235294117646, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(95.6642942583732, 185.4635294117647, 'X[0] <= 3.5\ngini = 0.391\nsamples = 274\nvalue = [201, 73]'),
#  Text(57.76901913875598, 172.6729411764706, 'X[3] <= 5.0\ngini = 0.281\nsamples = 160\nvalue = [133, 27]'),
#  Text(38.44593301435407, 159.88235294117646, 'X[1] <= 101.5\ngini = 0.49\nsamples = 21\nvalue = [12, 9]'),
#  Text(35.242105263157896, 147.09176470588235, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(41.64976076555024, 147.09176470588235, 'X[2] <= 87.0\ngini = 0.459\nsamples = 14\nvalue = [5, 9]'),
#  Text(38.44593301435407, 134.30117647058825, 'X[5] <= 44.1\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(35.242105263157896, 121.51058823529411, 'X[6] <= 0.227\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(32.038277511961724, 108.72, 'X[2] <= 55.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(28.83444976076555, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(35.242105263157896, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(38.44593301435407, 108.72, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(41.64976076555024, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(44.85358851674641, 134.30117647058825, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(77.09210526315789, 159.88235294117646, 'X[5] <= 45.45\ngini = 0.225\nsamples = 139\nvalue = [121, 18]'),
#  Text(65.27799043062201, 147.09176470588235, 'X[5] <= 30.95\ngini = 0.19\nsamples = 132\nvalue = [118, 14]'),
#  Text(51.26124401913876, 134.30117647058825, 'X[1] <= 123.0\ngini = 0.041\nsamples = 48\nvalue = [47, 1]'),
#  Text(48.057416267942585, 121.51058823529411, 'gini = 0.0\nsamples = 42\nvalue = [42, 0]'),
#  Text(54.46507177033493, 121.51058823529411, 'X[3] <= 22.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(51.26124401913876, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(57.6688995215311, 108.72, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(79.29473684210527, 134.30117647058825, 'X[6] <= 0.501\ngini = 0.262\nsamples = 84\nvalue = [71, 13]'),
#  Text(67.28038277511962, 121.51058823529411, 'X[5] <= 31.1\ngini = 0.155\nsamples = 59\nvalue = [54, 5]'),
#  Text(64.07655502392345, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(70.48421052631579, 108.72, 'X[2] <= 81.0\ngini = 0.128\nsamples = 58\nvalue = [54, 4]'),
#  Text(62.47464114832536, 95.92941176470588, 'X[5] <= 31.8\ngini = 0.073\nsamples = 53\nvalue = [51, 2]'),
#  Text(56.066985645933016, 83.13882352941175, 'X[1] <= 102.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(52.863157894736844, 70.34823529411764, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(59.27081339712919, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(68.8822966507177, 83.13882352941175, 'X[1] <= 120.5\ngini = 0.039\nsamples = 50\nvalue = [49, 1]'),
#  Text(65.67846889952153, 70.34823529411764, 'gini = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(72.08612440191388, 70.34823529411764, 'X[0] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(68.8822966507177, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(75.28995215311005, 57.557647058823534, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(78.49377990430622, 95.92941176470588, 'X[4] <= 72.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(75.28995215311005, 83.13882352941175, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(81.6976076555024, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(91.30909090909091, 121.51058823529411, 'X[5] <= 38.55\ngini = 0.435\nsamples = 25\nvalue = [17, 8]'),
#  Text(88.10526315789474, 108.72, 'X[5] <= 32.65\ngini = 0.494\nsamples = 18\nvalue = [10, 8]'),
#  Text(84.90143540669857, 95.92941176470588, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(91.30909090909091, 95.92941176470588, 'X[5] <= 35.45\ngini = 0.473\nsamples = 13\nvalue = [5, 8]'),
#  Text(88.10526315789474, 83.13882352941175, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(94.51291866028708, 83.13882352941175, 'X[5] <= 37.6\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(91.30909090909091, 70.34823529411764, 'X[4] <= 74.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(88.10526315789474, 57.557647058823534, 'X[4] <= 70.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(84.90143540669857, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(91.30909090909091, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(94.51291866028708, 57.557647058823534, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(97.71674641148326, 70.34823529411764, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(94.51291866028708, 108.72, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(88.90622009569378, 147.09176470588235, 'X[6] <= 0.844\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(85.70239234449761, 134.30117647058825, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(92.11004784688996, 134.30117647058825, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(133.55956937799044, 172.6729411764706, 'X[6] <= 0.904\ngini = 0.481\nsamples = 114\nvalue = [68, 46]'),
#  Text(130.35574162679427, 159.88235294117646, 'X[1] <= 94.5\ngini = 0.46\nsamples = 106\nvalue = [68, 38]'),
#  Text(104.1244019138756, 147.09176470588235, 'X[1] <= 28.5\ngini = 0.238\nsamples = 29\nvalue = [25, 4]'),
#  Text(100.92057416267943, 134.30117647058825, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(107.32822966507177, 134.30117647058825, 'X[6] <= 0.796\ngini = 0.137\nsamples = 27\nvalue = [25, 2]'),
#  Text(104.1244019138756, 121.51058823529411, 'X[0] <= 11.5\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(100.92057416267943, 108.72, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(107.32822966507177, 108.72, 'X[5] <= 31.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(104.1244019138756, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(110.53205741626795, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(110.53205741626795, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(156.58708133971294, 147.09176470588235, 'X[2] <= 83.0\ngini = 0.493\nsamples = 77\nvalue = [43, 34]'),
#  Text(143.3712918660287, 134.30117647058825, 'X[3] <= 26.5\ngini = 0.499\nsamples = 62\nvalue = [30, 32]'),
#  Text(126.55119617224881, 121.51058823529411, 'X[5] <= 38.25\ngini = 0.444\nsamples = 30\nvalue = [10, 20]'),
#  Text(123.34736842105264, 108.72, 'X[0] <= 4.5\ngini = 0.408\nsamples = 28\nvalue = [8, 20]'),
#  Text(116.93971291866029, 95.92941176470588, 'X[4] <= 50.0\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(113.73588516746412, 83.13882352941175, 'X[6] <= 0.144\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(110.53205741626795, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(116.93971291866029, 70.34823529411764, 'X[6] <= 0.387\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(113.73588516746412, 57.557647058823534, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(120.14354066985646, 57.557647058823534, 'X[2] <= 74.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(116.93971291866029, 44.767058823529396, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(123.34736842105264, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(120.14354066985646, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(129.75502392344498, 95.92941176470588, 'X[0] <= 7.5\ngini = 0.278\nsamples = 18\nvalue = [3, 15]'),
#  Text(126.55119617224881, 83.13882352941175, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(132.95885167464115, 83.13882352941175, 'X[6] <= 0.265\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(129.75502392344498, 70.34823529411764, 'X[4] <= 57.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(126.55119617224881, 57.557647058823534, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(132.95885167464115, 57.557647058823534, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(136.16267942583733, 70.34823529411764, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(129.75502392344498, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(160.19138755980862, 121.51058823529411, 'X[6] <= 0.513\ngini = 0.469\nsamples = 32\nvalue = [20, 12]'),
#  Text(148.97799043062201, 108.72, 'X[5] <= 33.45\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(145.77416267942584, 95.92941176470588, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(152.1818181818182, 95.92941176470588, 'X[6] <= 0.315\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(145.77416267942584, 83.13882352941175, 'X[5] <= 33.9\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(142.57033492822967, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(148.97799043062201, 70.34823529411764, 'X[2] <= 78.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(145.77416267942584, 57.557647058823534, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(152.1818181818182, 57.557647058823534, 'X[4] <= 87.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(148.97799043062201, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(155.38564593301436, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(158.58947368421053, 83.13882352941175, 'X[2] <= 60.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(155.38564593301436, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(161.7933014354067, 70.34823529411764, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(171.40478468899522, 108.72, 'X[0] <= 6.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(168.20095693779905, 95.92941176470588, 'X[1] <= 107.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(164.99712918660288, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(171.40478468899522, 83.13882352941175, 'X[3] <= 43.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(168.20095693779905, 70.34823529411764, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(174.6086124401914, 70.34823529411764, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(174.6086124401914, 95.92941176470588, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(169.80287081339713, 134.30117647058825, 'X[5] <= 41.2\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(166.59904306220096, 121.51058823529411, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(173.0066985645933, 121.51058823529411, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(136.76339712918661, 159.88235294117646, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(245.89377990430623, 198.25411764705882, 'X[5] <= 29.95\ngini = 0.475\nsamples = 224\nvalue = [87, 137]'),
#  Text(197.0354066985646, 185.4635294117647, 'X[1] <= 146.5\ngini = 0.429\nsamples = 61\nvalue = [42, 19]'),
#  Text(181.01626794258374, 172.6729411764706, 'X[2] <= 55.0\ngini = 0.239\nsamples = 36\nvalue = [31, 5]'),
#  Text(174.6086124401914, 159.88235294117646, 'X[3] <= 9.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(171.40478468899522, 147.09176470588235, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(177.81244019138757, 147.09176470588235, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(187.42392344497608, 159.88235294117646, 'X[1] <= 135.0\ngini = 0.165\nsamples = 33\nvalue = [30, 3]'),
#  Text(184.2200956937799, 147.09176470588235, 'X[0] <= 2.5\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(181.01626794258374, 134.30117647058825, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(187.42392344497608, 134.30117647058825, 'X[4] <= 69.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(181.01626794258374, 121.51058823529411, 'X[1] <= 133.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(177.81244019138757, 108.72, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(184.2200956937799, 108.72, 'X[0] <= 6.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(181.01626794258374, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(187.42392344497608, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(193.83157894736843, 121.51058823529411, 'X[4] <= 173.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(190.62775119617226, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(197.0354066985646, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(190.62775119617226, 147.09176470588235, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(213.05454545454546, 172.6729411764706, 'X[4] <= 14.5\ngini = 0.493\nsamples = 25\nvalue = [11, 14]'),
#  Text(203.44306220095694, 159.88235294117646, 'X[6] <= 0.18\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(200.23923444976077, 147.09176470588235, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(206.64688995215312, 147.09176470588235, 'X[1] <= 195.5\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(203.44306220095694, 134.30117647058825, 'X[0] <= 8.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(200.23923444976077, 121.51058823529411, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(206.64688995215312, 121.51058823529411, 'X[6] <= 0.206\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(203.44306220095694, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(209.8507177033493, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(209.8507177033493, 134.30117647058825, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(222.66602870813398, 159.88235294117646, 'X[4] <= 184.0\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(219.4622009569378, 147.09176470588235, 'X[6] <= 0.143\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(216.25837320574163, 134.30117647058825, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(222.66602870813398, 134.30117647058825, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(225.86985645933015, 147.09176470588235, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(294.75215311004786, 185.4635294117647, 'X[1] <= 165.5\ngini = 0.4\nsamples = 163\nvalue = [45, 118]'),
#  Text(267.5196172248804, 172.6729411764706, 'X[4] <= 252.5\ngini = 0.466\nsamples = 108\nvalue = [40, 68]'),
#  Text(248.29665071770336, 159.88235294117646, 'X[6] <= 0.265\ngini = 0.429\nsamples = 90\nvalue = [28, 62]'),
#  Text(232.2775119617225, 147.09176470588235, 'X[1] <= 155.0\ngini = 0.5\nsamples = 24\nvalue = [12, 12]'),
#  Text(229.07368421052632, 134.30117647058825, 'X[5] <= 34.1\ngini = 0.48\nsamples = 20\nvalue = [12, 8]'),
#  Text(222.66602870813398, 121.51058823529411, 'X[2] <= 95.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(219.4622009569378, 108.72, 'X[2] <= 81.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(216.25837320574163, 95.92941176470588, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(222.66602870813398, 95.92941176470588, 'X[5] <= 32.45\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(219.4622009569378, 83.13882352941175, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(225.86985645933015, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(225.86985645933015, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(235.48133971291867, 121.51058823529411, 'X[2] <= 77.0\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(232.2775119617225, 108.72, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(238.68516746411484, 108.72, 'X[4] <= 73.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(235.48133971291867, 95.92941176470588, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(241.888995215311, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(235.48133971291867, 134.30117647058825, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(264.3157894736842, 147.09176470588235, 'X[3] <= 49.5\ngini = 0.367\nsamples = 66\nvalue = [16, 50]'),
#  Text(261.11196172248805, 134.30117647058825, 'X[1] <= 164.5\ngini = 0.355\nsamples = 65\nvalue = [15, 50]'),
#  Text(257.9081339712919, 121.51058823529411, 'X[4] <= 142.0\ngini = 0.342\nsamples = 64\nvalue = [14, 50]'),
#  Text(251.50047846889953, 108.72, 'X[4] <= 137.5\ngini = 0.4\nsamples = 47\nvalue = [13, 34]'),
#  Text(248.29665071770336, 95.92941176470588, 'X[6] <= 1.551\ngini = 0.369\nsamples = 45\nvalue = [11, 34]'),
#  Text(245.09282296650719, 83.13882352941175, 'X[1] <= 141.5\ngini = 0.351\nsamples = 44\nvalue = [10, 34]'),
#  Text(233.07846889952154, 70.34823529411764, 'X[4] <= 29.0\ngini = 0.444\nsamples = 27\nvalue = [9, 18]'),
#  Text(229.87464114832537, 57.557647058823534, 'X[6] <= 0.437\ngini = 0.49\nsamples = 21\nvalue = [9, 12]'),
#  Text(215.4574162679426, 44.767058823529396, 'X[6] <= 0.302\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(212.25358851674642, 31.976470588235287, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(218.66124401913876, 31.976470588235287, 'X[5] <= 34.35\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(215.4574162679426, 19.185882352941178, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(221.86507177033494, 19.185882352941178, 'X[2] <= 40.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(218.66124401913876, 6.39529411764704, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(225.0688995215311, 6.39529411764704, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(244.29186602870814, 44.767058823529396, 'X[5] <= 39.95\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(237.8842105263158, 31.976470588235287, 'X[1] <= 129.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(234.68038277511963, 19.185882352941178, 'X[2] <= 40.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(231.47655502392345, 6.39529411764704, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(237.8842105263158, 6.39529411764704, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(241.08803827751197, 19.185882352941178, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(250.6995215311005, 31.976470588235287, 'X[5] <= 40.7\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(247.49569377990431, 19.185882352941178, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(253.90334928229666, 19.185882352941178, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(236.2822966507177, 57.557647058823534, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(257.1071770334928, 70.34823529411764, 'X[2] <= 66.0\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(253.90334928229666, 57.557647058823534, 'X[1] <= 148.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(250.6995215311005, 44.767058823529396, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(257.1071770334928, 44.767058823529396, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(260.311004784689, 57.557647058823534, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(251.50047846889953, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(254.7043062200957, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(264.3157894736842, 108.72, 'X[3] <= 27.0\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(261.11196172248805, 95.92941176470588, 'X[4] <= 197.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(257.9081339712919, 83.13882352941175, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(264.3157894736842, 83.13882352941175, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(267.5196172248804, 95.92941176470588, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(264.3157894736842, 121.51058823529411, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(267.5196172248804, 134.30117647058825, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(286.7425837320574, 159.88235294117646, 'X[0] <= 5.5\ngini = 0.444\nsamples = 18\nvalue = [12, 6]'),
#  Text(283.53875598086125, 147.09176470588235, 'X[2] <= 57.0\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(280.3349282296651, 134.30117647058825, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(286.7425837320574, 134.30117647058825, 'X[0] <= 4.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(280.3349282296651, 121.51058823529411, 'X[2] <= 72.0\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(277.1311004784689, 108.72, 'X[2] <= 67.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(273.92727272727274, 95.92941176470588, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(280.3349282296651, 95.92941176470588, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(283.53875598086125, 108.72, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(293.15023923444977, 121.51058823529411, 'X[4] <= 415.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(289.9464114832536, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(296.35406698564594, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(289.9464114832536, 147.09176470588235, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(321.9846889952153, 172.6729411764706, 'X[6] <= 1.428\ngini = 0.165\nsamples = 55\nvalue = [5, 50]'),
#  Text(315.577033492823, 159.88235294117646, 'X[6] <= 0.307\ngini = 0.113\nsamples = 50\nvalue = [3, 47]'),
#  Text(312.3732057416268, 147.09176470588235, 'X[6] <= 0.291\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(309.16937799043063, 134.30117647058825, 'X[3] <= 27.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(305.96555023923446, 121.51058823529411, 'X[5] <= 35.3\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(302.7617224880383, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(309.16937799043063, 108.72, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(312.3732057416268, 121.51058823529411, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(315.577033492823, 134.30117647058825, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(318.78086124401915, 147.09176470588235, 'gini = 0.0\nsamples = 36\nvalue = [0, 36]'),
#  Text(328.39234449760767, 159.88235294117646, 'X[1] <= 181.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(325.1885167464115, 147.09176470588235, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(331.59617224880384, 147.09176470588235, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

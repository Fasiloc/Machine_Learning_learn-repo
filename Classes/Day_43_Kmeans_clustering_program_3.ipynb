# %% [markdown]
# <a href="https://colab.research.google.com/github/Fasiloc/Machine_Learning_learn-repo/blob/main/Classes/Day_43_Kmeans_clustering_program_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import pandas as pd
from matplotlib import pyplot as plt

# %%
Data = {'x': [1,1,1,2,1,2,1,2],
        'y': [4,2,4,1,1,4,1,1],
        'z': [1,2,2,2,1,2,2,1]
       }

# %%
df=pd.DataFrame(Data,columns=['x','y','z'])
df
# Out:
#    x  y  z
# 0  1  4  1
# 1  1  2  2
# 2  1  4  2
# 3  2  1  2
# 4  1  1  1
# 5  2  4  2
# 6  1  1  2
# 7  2  1  1

# %%
kmeans = KMeans(n_clusters=2).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[1.4        1.2        1.6        0.8       ]
#  [1.33333333 4.         1.66666667 1.        ]]

# %%
fig = plt.figure(figsize=(12,15))
a = fig.add_subplot(projection='3d')
a.scatter(df['x'], df['y'], df['z'],c= kmeans.labels_.astype(float), s=100, alpha=0.5)
plt.xlabel('x-Axis')
plt.ylabel('y-Axis')
a.set_zlabel('Z-Axis')
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)

# %%
km.cluster_centers_
# Out:
# array([[1.33333333, 1.33333333, 2.        ],
#        [1.33333333, 4.        , 1.66666667],
#        [1.5       , 1.        , 1.        ]])

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
plt.scatter(df1.x,df1['y'],color = 'green')
plt.scatter(df2.x,df2['y'],color = 'red')
plt.scatter(df3.x,df3['y'],color = 'black')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='*',label = 'centroid')
plt.legend()
